# %% [markdown]
# # P3: Wrangle Open Street Map Data

# %%
import xml.etree.ElementTree as ET  # Use cElementTree or lxml if too slow

OSM_FILE = "kolkata.osm"  # Replace this with your osm file
SAMPLE_FILE = "kolkata_sample.osm"

k = 10 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %%
import xml.etree.ElementTree as ET 
import re


#Regular Expressions 
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
postal_code=re.compile(r'.*(\d{6}).*$')

#street mapping
mapping = { "St": "Street",
            "St.": "Street",
            "Rd":"Road",
            "Rd.":"Road",
            "Ave":"Avenue",
            "Ave.":"Avenue",
            "Expy":"Expressway",
            "Hwy":"Highway"
}

#Function to check valid Post Codes
def isPostCodeValid(postcode):
    return len(postcode)==6


#Refine street adress 
def refine_street_type(street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type in mapping:
            streetname.replace(street_type,mapping[street_type])

# %%
names=set()
et_parse_data=ET.iterparse('kolkata_sample.osm')
count=0
for _,elem in et_parse_data:
    count+=1
    keys = key_type(elem, keys)
    for t in elem.iter('tag'):
        if 'addr' in t.attrib['k']:
            if 'housename' in t.attrib['k']:
                m=postal_code.match(t.attrib['v'])
                if m:
                    print t.attrib['k']+' : '+t.attrib['v']
                    print 'postal_code in housename',m.groups()
            #print t.attrib['k']+' : '+t.attrib['v']
            names.add(t.attrib['k']+' : '+t.attrib['v'])
# Out:
# addr:housename : EE Block, Salt Lake City Kolkata, West Bengal 700091‎
# postal_code in housename (u'700091',)
# addr:housename : EE Block, Salt Lake City Kolkata, West Bengal 700091‎
# postal_code in housename (u'700091',)
# addr:housename : 6th Cross Road, DJ Block, Salt Lake CityKolkata, WB 700091
# postal_code in housename ('700091',)
# addr:housename : 6th Cross Road, DJ Block, Salt Lake CityKolkata, WB 700091
# postal_code in housename ('700091',)
# addr:housename : HC Block, Sector 3, Bidhannagar, Kolkata, West Bengal, 700106‎
# postal_code in housename (u'700106',)
# addr:housename : HC Block, Sector 3, Bidhannagar, Kolkata, West Bengal, 700106‎
# postal_code in housename (u'700106',)
# addr:housename : EE Block, Salt Lake City Kolkata, West Bengal 700091‎
# postal_code in housename (u'700091',)
# addr:housename : 6th Cross Road, DJ Block, Salt Lake CityKolkata, WB 700091
# postal_code in housename ('700091',)
# addr:housename : HC Block, Sector 3, Bidhannagar, Kolkata, West Bengal, 700106‎
# postal_code in housename (u'700106',)

# %%
names
# Out:
# {'addr:city : Kolkata',
#  'addr:city : Salt Lake (Bidhan Nagar)',
#  'addr:city : Saltlake (Bidhannagar)',
#  'addr:country : IN',
#  'addr:housename : 6th Cross Road, DJ Block, Salt Lake CityKolkata, WB 700091',
#  u'addr:housename : EE Block, Salt Lake City Kolkata, West Bengal 700091\u200e',
#  u'addr:housename : HC Block, Sector 3, Bidhannagar, Kolkata, West Bengal, 700106\u200e',
#  'addr:housename : IB 175, Sector III, Salt Lake City Kolkata',
#  'addr:housename : Sector III IB 201, IB Block, Salt Lake City, Kolkata, West Bengal',
#  'addr:housename : The French Loaf',
#  'addr:housenumber : #4A',
#  'addr:housenumber : 102',
#  'addr:housenumber : 106/A/3',
#  'addr:housenumber : 110/5/L',
#  'addr:housenumber : 111',
#  'addr:housenumber : 117',
#  'addr:housenumber : 118',
#  'addr:housenumber : 12/A',
#  'addr:housenumber : 120',
#  'addr:housenumber : 128',
#  'addr:housenumber : 134',
#  'addr:housenumber : 137',
#  'addr:housenumber : 138',
#  'addr:housenumber : 14',
#  'addr:housenumber : 144',
#  'addr:housenumber : 148',
#  'addr:housenumber : 149',
#  'addr:housenumber : 15',
#  'addr:housenumber : 152',
#  'addr:housenumber : 153',
#  'addr:housenumber : 154',
#  'addr:housenumber : 156',
#  'addr:housenumber : 157',
#  'addr:housenumber : 164',
#  'addr:housenumber : 166',
#  'addr:housenumber : 169',
#  'addr:housenumber : 172',
#  'addr:housenumber : 173',
#  'addr:housenumber : 179',
#  'addr:housenumber : 18',
#  'addr:housenumber : 180',
#  'addr:housenumber : 182',
#  'addr:housenumber : 183',
#  'addr:housenumber : 191',
#  'addr:housenumber : 193',
#  'addr:housenumber : 203',
#  'addr:housenumber : 204',
#  'addr:housenumber : 207',
#  'addr:housenumber : 210',
#  'addr:housenumber : 216',
#  'addr:housenumber : 217',
#  'addr:housenumber : 227',
#  'addr:housenumber : 229',
#  'addr:housenumber : 23',
#  'addr:housenumber : 237',
#  'addr:housenumber : 246',
#  'addr:housenumber : 248',
#  'addr:housenumber : 249',
#  'addr:housenumber : 250',
#  'addr:housenumber : 251',
#  'addr:housenumber : 255',
#  'addr:housenumber : 258',
#  'addr:housenumber : 260',
#  'addr:housenumber : 261',
#  'addr:housenumber : 268',
#  'addr:housenumber : 27',
#  'addr:housenumber : 278',
#  'addr:housenumber : 284',
#  'addr:housenumber : 285',
#  'addr:housenumber : 287',
#  'addr:housenumber : 29',
#  'addr:housenumber : 290',
#  'addr:housenumber : 292',
#  'addr:housenumber : 293',
#  'addr:housenumber : 298',
#  'addr:housenumber : 307',
#  'addr:housenumber : 316',
#  'addr:housenumber : 326',
#  'addr:housenumber : 330',
#  'addr:housenumber : 338',
#  'addr:housenumber : 339',
#  'addr:housenumber : 348',
#  'addr:housenumber : 35',
#  'addr:housenumber : 352',
#  'addr:housenumber : 362',
#  'addr:housenumber : 364',
#  'addr:housenumber : 372',
#  'addr:housenumber : 373',
#  'addr:housenumber : 38',
#  'addr:housenumber : 382',
#  'addr:housenumber : 392',
#  'addr:housenumber : 402',
#  'addr:housenumber : 41',
#  'addr:housenumber : 413',
#  'addr:housenumber : 415',
#  'addr:housenumber : 416',
#  'addr:housenumber : 421',
#  'addr:housenumber : 424',
#  'addr:housenumber : 427',
#  'addr:housenumber : 43',
#  'addr:housenumber : 434',
#  'addr:housenumber : 44',
#  'addr:housenumber : 447',
#  'addr:housenumber : 451',
#  'addr:housenumber : 490',
#  'addr:housenumber : 51',
#  'addr:housenumber : 52',
#  'addr:housenumber : 57',
#  'addr:housenumber : 58',
#  'addr:housenumber : 62',
#  'addr:housenumber : 63',
#  'addr:housenumber : 64',
#  'addr:housenumber : 7',
#  'addr:housenumber : 74',
#  'addr:housenumber : 75',
#  'addr:housenumber : 84',
#  'addr:housenumber : 9',
#  'addr:housenumber : 90',
#  'addr:housenumber : 91',
#  'addr:housenumber : 94',
#  'addr:housenumber : BG 32',
#  'addr:housenumber : phys & chem. dept.',
#  'addr:place : BD Block',
#  'addr:postcode : 700006',
#  'addr:postcode : 700015',
#  'addr:postcode : 700019',
#  'addr:postcode : 700027',
#  'addr:postcode : 700053',
#  'addr:postcode : 700064',
#  'addr:postcode : 700071',
#  'addr:postcode : 700091',
#  'addr:postcode : 700102',
#  'addr:postcode : 700106',
#  'addr:state : West Bengal',
#  'addr:street : 41, Jawaharlal Nehru Road, Middleton Row, Middleton St',
#  'addr:street : Camac Street',
#  'addr:street : Daud Ali Dutta Sarani(Sukea Row)',
#  'addr:street : Duff Street',
#  'addr:street : Gariahat Road',
#  'addr:street : Hana Para Rd',
#  'addr:street : Hazra Road',
#  'addr:street : New Road',
#  'addr:street : Radhanath Chowdhury Road',
#  'addr:street : Raja Santosh Road',
#  'addr:street : Theatre Road',
#  'addr:street : Tollygunge Circular Road, New Alipore',
#  'addr:suburb : Bidhan Nagar'}
